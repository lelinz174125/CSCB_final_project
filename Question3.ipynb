# %%
import celloracle as co
co.check_python_requirements()
# Out:
# Fontconfig warning: ignoring UTF-8: not a valid region tag
#      package_name installed_version required_version  requirement_satisfied
# 0           numpy            1.20.1             auto                   True
# 1           scipy             1.6.2             auto                   True
# 2          cython           0.29.28             auto                   True
# 3           numba            0.53.1           0.50.1                   True
# 4      matplotlib             3.4.3             auto                   True
# 5         seaborn            0.11.1             auto                   True
# 6    scikit-learn            0.24.2             auto                   True
# 7            h5py             3.6.0            3.1.0                   True
# 8          pandas             1.4.2            1.0.3                   True
# 9        velocyto           0.17.17             0.17                   True
# 10     umap-learn             0.5.2             auto                   True
# ...
